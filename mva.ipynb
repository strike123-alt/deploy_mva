# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('Clustered_Customer_Data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0           0    40.900749           0.818182      95.40              0.00
# 1           1  3202.467416           0.909091       0.00              0.00
# 2           2  2495.148862           1.000000     773.17            773.17
# 3           3  1666.670542           0.636364    1499.00           1499.00
# 4           4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 8945        8945   28.493517           1.000000     291.12              0.00
# 8946        8946   19.183215           1.000000     300.00              0.00
# 8947        8947   23.398673           0.833333     144.40              0.00
# 8948        8948   13.457564           0.833333       0.00              0.00
# 8949        8949  372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# ...

# %%
df.shape
# Out:
# (8950, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 19 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 0                        8950 non-null   int64
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0       BALANCE  BALANCE_FREQUENCY     PURCHASES  \
# count  8950.000000   8950.000000        8950.000000   8950.000000
# mean   4474.500000   1564.474828           0.877271   1003.204834
# std    2583.786788   2081.531879           0.236904   2136.634782
# min       0.000000      0.000000           0.000000      0.000000
# 25%    2237.250000    128.281915           0.888889     39.635000
# 50%    4474.500000    873.385231           1.000000    361.280000
# 75%    6711.750000   2054.140036           1.000000   1110.130000
# max    8949.000000  19043.138560           1.000000  49039.570000
#
#        ONEOFF_PURCHASES  INSTALLMENTS_PURCHASES  CASH_ADVANCE  \
# count       8950.000000             8950.000000   8950.000000
# mean         592.437371              411.067645    978.871112
# std         1659.887917              904.338115   2097.163877
# min            0.000000                0.000000      0.000000
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                          0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# Cluster                             0
# dtype: int64

# %%
df[df['MINIMUM_PAYMENTS'].isna()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, BALANCE, BALANCE_FREQUENCY, PURCHASES, ONEOFF_PURCHASES, INSTALLMENTS_PURCHASES, CASH_ADVANCE, PURCHASES_FREQUENCY, ONEOFF_PURCHASES_FREQUENCY, PURCHASES_INSTALLMENTS_FREQUENCY, CASH_ADVANCE_FREQUENCY, CASH_ADVANCE_TRX, PURCHASES_TRX, CREDIT_LIMIT, PAYMENTS, MINIMUM_PAYMENTS, PRC_FULL_PAYMENT, TENURE, Cluster]
# Index: []

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(columns=["Unnamed: 0"],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES',
#        'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
#        'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
#        'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
#        'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT',
#        'TENURE', 'Cluster'],
#       dtype='object')

# %%
df.shape
# Out:
# (8950, 18)

# %%
plt.figure(figsize=(30,45))
for i, col in enumerate(df.columns):
    if df[col].dtype != 'object':
        ax = plt.subplot(9, 2, i+1)
        sns.kdeplot(df[col], ax=ax)
        plt.xlabel(col)
        
plt.show()

# %%
plt.figure(figsize=(10,60))
for i in range(0,17):
    plt.subplot(17,1,i+1)
    sns.distplot(df[df.columns[i]],kde_kws={'color':'black','bw': 0.1,'lw':3,'label':'KDE'},hist_kws={'color':'g'})
    plt.title(df.columns[i])
plt.tight_layout()

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(), annot=True, cmap="Blues")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans,AgglomerativeClustering,DBSCAN,SpectralClustering
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn import tree
from sklearn import metrics

# %%
X_train = df.iloc[:, :-1]

# %%
X_train
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
Y_train = df.iloc[:, -1]

# %%
Y_train
# Out:
# 0       0
# 1       2
# 2       3
# 3       0
# 4       0
#        ..
# 8945    3
# 8946    3
# 8947    3
# 8948    0
# 8949    0
# Name: Cluster, Length: 8950, dtype: int64

# %%
scalar=StandardScaler()

# %%
scaled_df = scalar.fit_transform(X_train)

# %%
pca = PCA(n_components=2)
principal_components = pca.fit_transform(scaled_df)
pca_df = pd.DataFrame(data=principal_components ,columns=["PCA1","PCA2"])
pca_df
# Out:
#           PCA1      PCA2
# 0    -1.682217 -1.076445
# 1    -1.138286  2.506492
# 2     0.969677 -0.383530
# 3    -0.873623  0.043174
# 4    -1.599432 -0.688577
# ...        ...       ...
# 8945 -0.359629 -2.016145
# 8946 -0.564366 -1.639117
# 8947 -0.926203 -1.810784
# 8948 -2.336550 -0.657964
# 8949 -0.556429 -0.400479
#
# [8950 rows x 2 columns]

# %%
inertia = []
range_val = range(1,15)
for i in range_val:
    kmean = KMeans(n_clusters=i)
    kmean.fit_predict(pd.DataFrame(scaled_df))
    inertia.append(kmean.inertia_)
plt.plot(range_val,inertia,'bx-')
plt.xlabel('Values of K') 
plt.ylabel('Inertia') 
plt.title('The Elbow Method using Inertia') 
plt.show()

# %%
kmeans_model=KMeans(4)
kmeans_model.fit_predict(scaled_df)
pca_df_kmeans= pd.concat([pca_df,pd.DataFrame({'cluster':kmeans_model.labels_})],axis=1)

# %%
plt.figure(figsize=(8,8))
ax=sns.scatterplot(x="PCA1",y="PCA2",hue="cluster",data=pca_df_kmeans,palette=['red','green','blue','black'])
plt.title("Clustering using K-Means Algorithm")
plt.show()

# %%
cluster_centers = pd.DataFrame(data=kmeans_model.cluster_centers_, columns = [X_train.columns])

# %%
cluster_centers = scalar.inverse_transform(cluster_centers)
cluster_centers = pd.DataFrame(data=cluster_centers,columns=[X_train.columns])
cluster_centers
# Out:
#        BALANCE BALANCE_FREQUENCY    PURCHASES ONEOFF_PURCHASES  \
# 0  3556.148177          0.986911  7680.432073      5099.738293
# 1  4581.655892          0.968438   493.151346       313.745458
# 2  1004.174667          0.789071   270.138946       209.672874
# 3   895.952109          0.935089  1237.326426       594.681356
#
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0            2582.157195   686.680975            0.946548
# 1             179.489843  4485.168482            0.284523
# 2              60.733767   589.719347            0.170947
# 3             642.919610   210.821081            0.885524
#
#   ONEOFF_PURCHASES_FREQUENCY PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   0.739667                         0.788577
# 1                   0.136967                         0.183199
# 2                   0.086392                         0.081217
# 3                   0.297424                         0.711995
#
# ...

# %%
cluster_df = pd.concat([X_train,pd.DataFrame({'Cluster':kmeans_model.labels_})],axis=1)
cluster_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
cluster_1_df = cluster_df[cluster_df["Cluster"] == 0]
cluster_1_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 6      627.260806           1.000000    7091.01           6402.63
# 21    6369.531318           1.000000    6359.95           5910.04
# 57    2386.330629           1.000000    5217.62           4789.09
# 84    1935.362486           1.000000    4915.60           4515.34
# 90    9381.255094           1.000000    5100.07           1147.83
# ...           ...                ...        ...               ...
# 8215  4436.557694           1.000000    6005.90           5838.38
# 8541  3326.323283           1.000000    8209.77           2218.28
# 8662   599.909949           1.000000    4947.32           3149.59
# 8689   368.318662           0.909091    8053.95           8053.95
# 8737  2533.618119           0.909091    5633.83           2985.92
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 6                     688.38      0.000000             1.000000
# ...

# %%
cluster_2_df = cluster_df[cluster_df["Cluster"]==1]
cluster_2_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 1     3202.467416           0.909091       0.00              0.00
# 15    6886.213231           1.000000    1611.70              0.00
# 23    3800.151377           0.818182    4248.35           3454.56
# 24    5368.571219           1.000000       0.00              0.00
# 28    7152.864372           1.000000     387.05            204.55
# ...           ...                ...        ...               ...
# 8857  2330.222764           1.000000    1320.00              0.00
# 8858   812.934042           1.000000      50.00             50.00
# 8869  2171.222526           1.000000     791.18            791.18
# 8915   381.341657           1.000000      78.00              0.00
# 8941  5967.475270           0.833333     214.55              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 1                       0.00   6442.945483             0.000000
# ...

# %%
cluster_3_df = cluster_df[cluster_df["Cluster"]==2]
cluster_3_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# 8     1014.926473           1.000000     861.49            661.49
# 9      152.225975           0.545455    1281.60           1281.60
# ...           ...                ...        ...               ...
# 8939   728.352548           1.000000     734.40            734.40
# 8943     5.871712           0.500000      20.90             20.90
# 8944   193.571722           0.833333    1012.73           1012.73
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                       95.4      0.000000             0.166667
# ...

# %%
cluster_4_df = cluster_df[cluster_df["Cluster"] == 3]
cluster_4_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 2     2495.148862           1.000000     773.17            773.17
# 5     1809.828751           1.000000    1333.28              0.00
# 7     1823.652743           1.000000     436.20              0.00
# 10    1293.124939           1.000000     920.12              0.00
# 12    1516.928620           1.000000    3217.99           2500.23
# ...           ...                ...        ...               ...
# 8940   130.838554           1.000000     591.24              0.00
# 8942    40.829749           1.000000     113.28              0.00
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 2                       0.00           0.0             1.000000
# ...

# %%
sns.countplot(x='Cluster', data=cluster_df)
# Out:
# <AxesSubplot:xlabel='Cluster', ylabel='count'>

# %%
for c in cluster_df.drop(['Cluster'],axis=1):
    grid= sns.FacetGrid(cluster_df, col='Cluster')
    grid= grid.map(plt.hist, c)
plt.show()

# %% [markdown]
# ## Fowlkes-Mallows Score
# ### The Fowlkes-Mallows function measures the similarity of two clustering of a set of points. It may be defined as the geometric mean of the pairwise precision and recall.

# %%
from sklearn.metrics.cluster import fowlkes_mallows_score
fowlkes_mallows_score(Y_train, kmeans_model.labels_)
# Out:
# 0.9964075956167303

# %%
from sklearn.metrics.cluster import contingency_matrix
contingency_matrix(Y_train, kmeans_model.labels_)
# Out:
# array([[   0,   14, 3962,    0],
#        [ 409,    0,    0,    0],
#        [   1, 1197,    0,    0],
#        [   0,    0,    4, 3363]], dtype=int64)

# %%
X = cluster_df.drop(['Cluster'],axis=1)
y= cluster_df[['Cluster']]
X_Train, X_Test, y_Train, y_Test =train_test_split(X, y, test_size=0.3,random_state=3)

# %%
X_train
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
X_test
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 5535    76.673877           0.777778     410.90              0.00
# 7828   645.406005           1.000000       0.00              0.00
# 1680  4977.237859           1.000000      61.99             61.99
# 4518   380.517893           1.000000    2590.27           2102.46
# 6131    41.011184           1.000000    1314.75            125.19
# ...           ...                ...        ...               ...
# 265   8097.334733           1.000000    3999.92            200.00
# 5034    13.221335           0.857143     108.84              0.00
# 1278  1770.072581           1.000000       0.00              0.00
# 285   4246.430225           1.000000       0.00              0.00
# 1120  4688.103434           1.000000       0.00              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 5535                  410.90      0.000000             0.666667
# ...

# %%
model= DecisionTreeClassifier(criterion="entropy")
model.fit(X_Train, y_Train)
y_pred = model.predict(X_Test)

# %%
print(f'{metrics.confusion_matrix(y_test, y_pred)}\n')
print(classification_report(y_Test, y_pred))
# Out:
# [[   1   23 1114   32]
#  [   0  335   34   11]
#  [ 107    0    2    9]
#  [  13   14   22  968]]
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91       121
#            1       0.90      0.88      0.89       380
#            2       0.95      0.95      0.95      1162
#            3       0.95      0.95      0.95      1022
#
#     accuracy                           0.94      2685
#    macro avg       0.93      0.92      0.92      2685
# weighted avg       0.94      0.94      0.94      2685

# %%
# import pickle
# with open('model.pkl', 'rb') as f:
#     data = pickle.load(f)

# %%
import pickle
file_name='model.pkl'
f = open(file_name,'wb')
pickle.dump(model,f)
f.close()

# %%
from sklearn_extra.cluster import KMedoids

# %%
pca = PCA(n_components=2)
principal_components = pca.fit_transform(scaled_df)
pca_df = pd.DataFrame(data=principal_components ,columns=["PCA1","PCA2"])
pca_df
# Out:
#           PCA1      PCA2
# 0    -1.682221 -1.076451
# 1    -1.138304  2.506475
# 2     0.969697 -0.383525
# 3    -0.873625  0.043160
# 4    -1.599436 -0.688578
# ...        ...       ...
# 8945 -0.359629 -2.016143
# 8946 -0.564362 -1.639126
# 8947 -0.926203 -1.810784
# 8948 -2.336556 -0.657961
# 8949 -0.556421 -0.400466
#
# [8950 rows x 2 columns]

# %%
kmedoids_model=KMedoids(4)
kmedoids_model.fit_predict(scaled_df)
pca_df_kmedoids= pd.concat([pca_df,pd.DataFrame({'cluster':kmedoids_model.labels_})],axis=1)

# %%
plt.figure(figsize=(8,8))
ax=sns.scatterplot(x="PCA1",y="PCA2",hue="cluster",data=pca_df_kmedoids,palette=['red','green','blue','black'])
plt.title("Clustering using KMedoids Algorithm")
plt.show()

# %%
distortions = list()
for i in range(1, 10):
    km = KMedoids(
        n_clusters=i
    )
    km.fit(scaled_df)
    distortions.append(km.inertia_)
print(distortions)
# Out:
# [32079.30943728477, 28503.03581262063, 26695.535899909595, 25318.413758971634, 24416.998612201816, 25049.799315113924, 23869.64560191183, 23733.375126225492, 21908.91399036018]

# %%
for i in range(2, 8):    
    k_model=KMedoids(i)
    k_model.fit_predict(scaled_df)
    pca_df_km= pd.concat([pca_df,pd.DataFrame({'cluster':k_model.labels_})],axis=1)
    plt.figure(figsize=(8,8))
    ax=sns.scatterplot(x="PCA1",y="PCA2",hue="cluster",data=pca_df_km)
    plt.title("Clustering using KMedoids Algorithm")
    plt.show()

# %%
kmedoids_centers = pd.DataFrame(data=kmedoids_model.cluster_centers_, columns = [X_train.columns])

# %%
kmedoids_centers = scalar.inverse_transform(cluster_centers)
kmedoids_centers = pd.DataFrame(data=kmedoids_centers,columns=[X_train.columns])
kmedoids_centers
# Out:
#         BALANCE BALANCE_FREQUENCY     PURCHASES ONEOFF_PURCHASES  \
# 0  9.029573e+12          1.144795  2.660230e+12     9.631650e+11
# 1  4.131553e+13          1.147194  4.786356e+12     1.426152e+12
# 2  3.242220e+13          1.147450  7.622651e+13     2.383887e+13
# 3  8.178315e+12          1.146778  1.222791e+13     2.758101e+12
#
#   INSTALLMENTS_PURCHASES  CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0           4.639667e+10  5.417266e+12            0.777383
# 1           1.325984e+11  4.134866e+13            0.784477
# 2           1.925951e+12  6.422607e+12            0.827305
# 3           4.815827e+11  1.969389e+12            0.823513
#
#   ONEOFF_PURCHASES_FREQUENCY PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   0.283173                         0.572103
# 1                   0.284501                         0.578287
# 2                   0.300600                         0.616277
# 3                   0.288839                         0.611645
#
# ...

# %%
cluster_df = pd.concat([X_train,pd.DataFrame({'kmedoids_model':kmedoids_model.labels_})],axis=1)
cluster_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
cluster_df = pd.concat([X_train,pd.DataFrame({'kmedoids_model':kmedoids_model.labels_})],axis=1)
cluster_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   BALANCE                           8950 non-null   float64
#  1   BALANCE_FREQUENCY                 8950 non-null   float64
#  2   PURCHASES                         8950 non-null   float64
#  3   ONEOFF_PURCHASES                  8950 non-null   float64
#  4   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  5   CASH_ADVANCE                      8950 non-null   float64
#  6   PURCHASES_FREQUENCY               8950 non-null   float64
#  7   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  8   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  9   CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  10  CASH_ADVANCE_TRX                  8950 non-null   int64
# ...

# %%
sns.countplot(x='kmedoids_model', data=cluster_df)
# Out:
# <AxesSubplot:xlabel='kmedoids_model', ylabel='count'>

# %%
for c in cluster_df.drop(['kmedoids_model'],axis=1):
    grid= sns.FacetGrid(cluster_df, col='kmedoids_model')
    grid= grid.map(plt.hist, c)
plt.show()

# %%
fowlkes_mallows_score(Y_train, kmedoids_model.labels_)
# Out:
# 0.688160985233048

# %%
from sklearn.metrics.cluster import contingency_matrix
contingency_matrix(Y_train, kmeans_model.labels_)
# Out:
# array([[3961,   15,    0,    0],
#        [   0,    0,  395,   14],
#        [   0, 1196,    1,    1],
#        [  26,    0,    0, 3341]], dtype=int64)
